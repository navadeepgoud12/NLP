# %%
corpus = "Dr. APJ Abdul Kalam’s speeches, particularly to youth, emphasized dreaming big, working with integrity, and overcoming obstacles to make India a developed nation. He advocated for self-reliance, technological advancement, and developing a scientific temper while combining knowledge with human values."

# %%
from nltk.stem import PorterStemmer

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\DELL
# [nltk_data]     ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
stemmer = PorterStemmer()

# %%
sentences = nltk.sent_tokenize(corpus)

# %%
type(sentences)
# Out:
# list

# %%
## apply stopwords and filter then apply stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['dr. apj abdul kalam ’ speech , particularli youth , emphas dream big , work integr , overcom obstacl make india develop nation .',
#  'he advoc self-reli , technolog advanc , develop scientif temper combin knowledg human valu .']

# %%
from nltk.stem import SnowballStemmer

# %%
snowball = SnowballStemmer("english")

# %%
## apply stopwords and filter then apply stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [snowball.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['dr. apj abdul kalam ’ speech , particular youth , empha dream big , work integr , overcom obstacl make india develop nation .',
#  'advoc self-r , technolog advanc , develop scientif temper combin knowledg human valu .']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [snowball.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['dr. apj abdul kalam ’ speech , particular youth , emphas dream big , work integr , overcom obstacl make india develop nation .',
#  'he advoc self-reli , technolog advanc , develop scientif temper combin knowledg human valu .']
