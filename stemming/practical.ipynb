# %% [markdown]
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of the words known as lemma

# %%
## comments of product is a positive or negitive review
# reviews -----> eat,eating,eats,go,goes,going

# %% [markdown]
# ## PorterStemer

# %%
words = ['eating','eat','eats','drink','drinking','program','programs']

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()
for word in words:
    print(word+"------>"+stemmer.stem(word))
# Out:
# eating------>eat
# eat------>eat
# eats------>eat
# drink------>drink
# drinking------>drink
# program------>program
# programs------>program

# %%
stemmer.stem('congratulations')
# Out:
# 'congratul'

# %%
stemmer.stem("helpful")
# Out:
# 'help'

# %%
## RegexStemmer

from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|es$|able',min=4)

# %%
reg_stemmer.stem("navas")
# Out:
# 'nava'

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("navable")
# Out:
# 'nav'

# %%
from nltk.stem import SnowballStemmer

# %%
snowballStemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowballStemmer.stem(word))
# Out:
# eating---->eat
# eat---->eat
# eats---->eat
# drink---->drink
# drinking---->drink
# program---->program
# programs---->program

# %%
stemmer.stem('fairly'),stemmer.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
snowballStemmer.stem('fairly'),snowballStemmer.stem('sportingly')
# Out:
# ('fair', 'sport')

# %% [markdown]
# WordNet Lemmatizer is an NLP technique that reduces words to their base or dictionary form (lemma) using lexical knowledge from the WordNet database.

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\DELL
# [nltk_data]     ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating---->eat
# eat---->eat
# eats---->eat
# drink---->drink
# drinking---->drink
# program---->program
# programs---->program

# %%
lemmatizer.lemmatize("history",pos='v')
# Out:
# 'history'

# %% [markdown]
# # parts of speech taging

# %%
"taj mahal is a beautiful place"
# Out:
# 'taj mahal is a beautiful place'

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\DELL ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\DELL
# [nltk_data]     ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(nltk.pos_tag("taj mahal is a beautiful place".split()))
# Out:
# [('taj', 'NN'), ('mahal', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('place', 'NN')]

# %% [markdown]
# # named entity recognition

# %%
sentence = "hello Navadeep you have wish to vist abroad"

# %%
words = nltk.word_tokenize(sentence)

# %%
words
# Out:
# ['hello', 'Navadeep', 'you', 'have', 'wish', 'to', 'vist', 'abroad']

# %%
# pos_tag for word
tag_word = nltk.pos_tag(words)
tag_word
# Out:
# [('hello', 'JJ'),
#  ('Navadeep', 'NNP'),
#  ('you', 'PRP'),
#  ('have', 'VBP'),
#  ('wish', 'JJ'),
#  ('to', 'TO'),
#  ('vist', 'VB'),
#  ('abroad', 'RB')]

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to C:\Users\DELL
# [nltk_data]     ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to C:\Users\DELL
# [nltk_data]     ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# True

# %%
#named recognition
nltk.ne_chunk(tag_word).draw()
